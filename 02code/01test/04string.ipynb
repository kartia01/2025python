# %%
print("test")
# Out:
# test

# %%
st = '이름 : 임 \n 윤섭'
print(st)
# Out:
# 이름 : 임
#  윤섭

# %%
st = "이름 : 임 \n 윤섭"
print(st)
# Out:
# 이름 : 임
#  윤섭

# %%
st = "이름 : \' 임\n윤섭 \'"
print(st)
# Out:
# 이름 : ' 임
# 윤섭 '

# %%
st1 = "이름 : \' 임윤섭 \' \t 안녕하세요"
print(st1)
# Out:
# 이름 : ' 임윤섭 ' 	 안녕하세요

# %%
st2 = 'abc'
print(len(st2))
print(st2[1])
# Out:
# 3
# b

# %%
st3 = 'abcdef'
for i in range(len(st3)):
    print(st3[i], end="" if i == len(st3)-1 else "-")
# Out:
# a-b-c-d-e-f

# %%
st4 = 'abcde'
print(st4[2:len(st4)-1])
# Out:
# cd

# %%
st5 = input("문자열 : ")
# st5 = "hello"
for i in range(len(st5)-1,-1,-1) :
    print(st5[i], end=" ")
# Out:
# f d s a

# %%
for i in range(1,10,-1):
    print(i,end=" ")

# %%
st6 = "zxcvbn"
print(st6[::-1])
# Out:
# nbvcxz

# %%
lower_list = []

while True:
    s = input("영어단어 :")
    if s == "exit":
        break
    lower_list.append(s.lower())

for word in lower_list:
    print(word)
# Out:
# test
