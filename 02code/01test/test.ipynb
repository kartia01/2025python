# %% [markdown]
# ### 제목
# **test**
# test1
# - 데이터수집
# - 데이터 전처리
#     - 결측치 처리
#     - 이상치
#
# 1. 데이터 불러오기
# 2. 모델학습
# 3. 결과평가
#
# `print("hello python")`
#
# ```python
# print("hello python")
# df=pd.read_csv("test.csv")
# ```
#
# ---
#
# |컬럼|설명|
# |----|----|
# |x   | 입력 |
#
# 구글링크 : [구글](http://google.com)
# ![이미지](이미지경로)
#
# ---
#
# - [ ] 데이터로드
# - [ ] 데스트

# %%
print("test")
# Out:
# test
