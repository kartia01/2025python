# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.melon.com/chart/'

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36',
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7'
}

res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text,"html.parser")
# print(soup)

# title_one = soup.select_one("#tb_list table .lst50 .ellipsis.rank01 a")
# print(title_one.text)

top_50 = soup.select("#lst50 > td > div")

type(top_50)
len(top_50)

for row in top_50:
    rank = row.select_one('span.rank')
    # print(rank)
    if rank is not None:
        print(rank.text,end=". ")

    title = row.select_one('.ellipsis.rank01 > span > a')
    if title is not None:
        print(title.text, end= " - ")

    singer = row.select_one('.ellipsis.rank02 > span > a')
    if singer is not None:
        print(singer.text)
# Out:
# 1. Good Goodbye - 화사 (HWASA)
# 2. 타임캡슐 - 다비치
# 3. Drowning - WOODZ
# 4. Blue Valentine - NMIXX
# 5. 사랑하게 될 거야 - 한로로
# 6. SPAGHETTI (feat. j-hope of BTS) - LE SSERAFIM (르세라핌)
# 7. ONE MORE TIME - ALLDAY PROJECT
# 8. Golden - HUNTR/X
# 9. 멸종위기사랑 - 이찬혁
# 10. 힙합보단 사랑, 사랑보단 돈 (Feat. 베이식) - 노아주다 (noahjooda)
# 11. 어제보다 슬픈 오늘 - 우디 (Woody)
# 12. 하얀 그리움 - 프로미스나인
# 13. 뛰어(JUMP) - BLACKPINK
# 14. 달리 표현할 수 없어요 - 로이킴
# 15. Zoo (From "Zootopia 2"/Soundtrack Version) - Disney
# 16. 0+0 - 한로로
# 17. NOT CUTE ANYMORE - 아일릿(ILLIT)
# 18. 첫 눈 - EXO
# 19. FAMOUS - ALLDAY PROJECT
# 20. 모르시나요(PROD.로코베리) - 조째즈
# 21. 너의 모든 순간 - 성시경
# 22. toxic till the end - 로제 (ROSÉ)
# 23. like JENNIE - 제니 (JENNIE)
# 24. Soda Pop - KPop Demon Hunters Cast
# 25. HOME SWEET HOME (feat. 태양, 대성) - G-DRAGON
# 26. 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 - AKMU (악뮤)
# 27. 내게 사랑이 뭐냐고 물어본다면 - 로이킴
# 28. 천상연 - 이창섭
# 29. 시작의 아이 ❍ - 박다혜
# 30. 너에게 닿기를 - 10CM
# 31. 오늘만 I LOVE YOU - BOYNEXTDOOR
# 32. 청춘만화 - 이무진
# 33. OVERDRIVE - TWS (투어스)
# 34. Whiplash - aespa
# 35. 나는 반딧불 - 황가람
# 36. REBEL HEART - IVE (아이브)
# 37. Hollywood Action - BOYNEXTDOOR
# 38. IRIS OUT - Kenshi Yonezu
# 39. HAPPY - DAY6 (데이식스)
# 40. XOXZ - IVE (아이브)
# 41. 한 페이지가 될 수 있게 - DAY6 (데이식스)
# 42. 모든 날, 모든 순간 (Every day, Every Moment) - 폴킴
# 43. 사랑은 늘 도망가 - 임영웅
# 44. 한번 더 이별 - 이창섭
# 45. 소나기 - 이클립스 (ECLIPSE)
# 46. 눈사람 - 정승환
# 47. FOCUS - Hearts2Hearts (하츠투하츠)
# 48. 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) - 너드커넥션 (Nerd Connection)
# 49. APT. - 로제 (ROSÉ)
# 50. 운명 (2025) - 먼데이 키즈
